# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 730

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid="+ weather_api_key

# %%
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 45.64,
#   'feels_like': 37.51,
#   'temp_min': 42.57,
#   'temp_max': 48.13,
#   'pressure': 999,
#   'humidity': 44},
#  'visibility': 10000,
#  'wind': {'speed': 21.85, 'deg': 250, 'gust': 28.77},
#  'clouds': {'all': 75},
#  'dt': 1648416601,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1648377318,
#   'sunset': 1648422221},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):
 # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city
        
    #log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
    
    try:
    #Run an API request for each of the cities.
         #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Country": city_country,
                        "Current Description":city_weather_description})
    except:
          print("City not found. Skipping...")
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cockburn town
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | tahe
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | coihaique
# Processing Record 7 of Set 1 | lompoc
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | esperance
# Processing Record 13 of Set 1 | vestmannaeyjar
# Processing Record 14 of Set 1 | cabo san lucas
# Processing Record 15 of Set 1 | provideniya
# Processing Record 16 of Set 1 | srednekolymsk
# Processing Record 17 of Set 1 | opuwo
# Processing Record 18 of Set 1 | kununurra
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | hervey bay
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | nanortalik
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | hobyo
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | ciudad bolivar
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | taoudenni
# Processing Record 34 of Set 1 | castro
# Processing Record 35 of Set 1 | banda aceh
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | cidreira
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | narsaq
# Processing Record 41 of Set 1 | carnarvon
# Processing Record 42 of Set 1 | airai
# Processing Record 43 of Set 1 | gazli
# Processing Record 44 of Set 1 | mahebourg
# Processing Record 45 of Set 1 | dolores
# Processing Record 46 of Set 1 | manono
# Processing Record 47 of Set 1 | flinders
# Processing Record 48 of Set 1 | unguia
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | nhulunbuy
# Processing Record 1 of Set 2 | codrington
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | mount pleasant
# Processing Record 4 of Set 2 | santos dumont
# Processing Record 5 of Set 2 | kosovska mitrovica
# Processing Record 6 of Set 2 | spartanburg
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | cologno al serio
# Processing Record 9 of Set 2 | alofi
# Processing Record 10 of Set 2 | udimskiy
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | saint-philippe
# Processing Record 13 of Set 2 | dakar
# Processing Record 14 of Set 2 | odesskoye
# Processing Record 15 of Set 2 | hithadhoo
# Processing Record 16 of Set 2 | vao
# Processing Record 17 of Set 2 | constitucion
# Processing Record 18 of Set 2 | mapiripan
# Processing Record 19 of Set 2 | bandarbeyla
# Processing Record 20 of Set 2 | solnechnyy
# Processing Record 21 of Set 2 | fort nelson
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | faanui
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | manavgat
# Processing Record 26 of Set 2 | xichang
# Processing Record 27 of Set 2 | san javier
# Processing Record 28 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | sohag
# Processing Record 31 of Set 2 | sembabule
# Processing Record 32 of Set 2 | zhezkazgan
# Processing Record 33 of Set 2 | baruun-urt
# Processing Record 34 of Set 2 | umbauba
# Processing Record 35 of Set 2 | brazzaville
# Processing Record 36 of Set 2 | norman wells
# Processing Record 37 of Set 2 | pemangkat
# Processing Record 38 of Set 2 | shadegan
# Processing Record 39 of Set 2 | thompson
# Processing Record 40 of Set 2 | victoria
# Processing Record 41 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 2 | fomboni
# Processing Record 43 of Set 2 | guantanamo
# Processing Record 44 of Set 2 | christchurch
# Processing Record 45 of Set 2 | banjar
# Processing Record 46 of Set 2 | bhadrachalam
# Processing Record 47 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 49 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 3 | sitka
# Processing Record 2 of Set 3 | kunyang
# Processing Record 3 of Set 3 | vila franca do campo
# Processing Record 4 of Set 3 | takoradi
# Processing Record 5 of Set 3 | filadelfia
# Processing Record 6 of Set 3 | morondava
# Processing Record 7 of Set 3 | tiksi
# Processing Record 8 of Set 3 | oranjemund
# Processing Record 9 of Set 3 | vaini
# Processing Record 10 of Set 3 | tura
# Processing Record 11 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 3 | ulundi
# Processing Record 13 of Set 3 | hami
# Processing Record 14 of Set 3 | severo-kurilsk
# Processing Record 15 of Set 3 | atuona
# Processing Record 16 of Set 3 | portland
# Processing Record 17 of Set 3 | port blair
# Processing Record 18 of Set 3 | loukhi
# Processing Record 19 of Set 3 | punta alta
# Processing Record 20 of Set 3 | yulara
# Processing Record 21 of Set 3 | dikson
# Processing Record 22 of Set 3 | dingle
# Processing Record 23 of Set 3 | bonavista
# Processing Record 24 of Set 3 | port hedland
# Processing Record 25 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 3 | nome
# Processing Record 27 of Set 3 | lhokseumawe
# Processing Record 28 of Set 3 | eyl
# Processing Record 29 of Set 3 | pa sang
# Processing Record 30 of Set 3 | cumaribo
# City not found. Skipping...
# Processing Record 31 of Set 3 | port lincoln
# Processing Record 32 of Set 3 | shellbrook
# Processing Record 33 of Set 3 | pochutla
# Processing Record 34 of Set 3 | inyonga
# Processing Record 35 of Set 3 | donskoye
# Processing Record 36 of Set 3 | coxim
# Processing Record 37 of Set 3 | batagay
# Processing Record 38 of Set 3 | zapolyarnyy
# Processing Record 39 of Set 3 | ambon
# Processing Record 40 of Set 3 | sao sepe
# Processing Record 41 of Set 3 | kayerkan
# Processing Record 42 of Set 3 | kalmunai
# Processing Record 43 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 44 of Set 3 | bogorodskoye
# Processing Record 45 of Set 3 | clyde river
# Processing Record 46 of Set 3 | ponta do sol
# Processing Record 47 of Set 3 | tuktoyaktuk
# Processing Record 48 of Set 3 | san patricio
# Processing Record 49 of Set 3 | dhidhdhoo
# Processing Record 50 of Set 3 | berlevag
# Processing Record 1 of Set 4 | inuvik
# Processing Record 2 of Set 4 | amahai
# Processing Record 3 of Set 4 | longyearbyen
# Processing Record 4 of Set 4 | phitsanulok
# Processing Record 5 of Set 4 | sao filipe
# Processing Record 6 of Set 4 | hofn
# Processing Record 7 of Set 4 | syracuse
# Processing Record 8 of Set 4 | shostka
# Processing Record 9 of Set 4 | winslow
# Processing Record 10 of Set 4 | sulangan
# Processing Record 11 of Set 4 | deputatskiy
# Processing Record 12 of Set 4 | freeport
# Processing Record 13 of Set 4 | swellendam
# Processing Record 14 of Set 4 | mar del plata
# Processing Record 15 of Set 4 | tasiilaq
# Processing Record 16 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 4 | tokur
# Processing Record 18 of Set 4 | gunjur
# Processing Record 19 of Set 4 | nyurba
# Processing Record 20 of Set 4 | katsuura
# Processing Record 21 of Set 4 | igunga
# Processing Record 22 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 23 of Set 4 | tres passos
# Processing Record 24 of Set 4 | sharanga
# Processing Record 25 of Set 4 | shouguang
# Processing Record 26 of Set 4 | barrow
# Processing Record 27 of Set 4 | caravelas
# Processing Record 28 of Set 4 | karratha
# Processing Record 29 of Set 4 | geraldton
# Processing Record 30 of Set 4 | georgetown
# Processing Record 31 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 4 | usinsk
# Processing Record 33 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 4 | akdepe
# Processing Record 35 of Set 4 | maarianhamina
# Processing Record 36 of Set 4 | zelenoborskiy
# Processing Record 37 of Set 4 | trapani
# Processing Record 38 of Set 4 | asyut
# Processing Record 39 of Set 4 | klaksvik
# Processing Record 40 of Set 4 | vardo
# Processing Record 41 of Set 4 | grindavik
# Processing Record 42 of Set 4 | dunedin
# Processing Record 43 of Set 4 | touros
# Processing Record 44 of Set 4 | naryan-mar
# Processing Record 45 of Set 4 | trairi
# Processing Record 46 of Set 4 | kruisfontein
# Processing Record 47 of Set 4 | montlucon
# Processing Record 48 of Set 4 | cherskiy
# Processing Record 49 of Set 4 | preobrazheniye
# Processing Record 50 of Set 4 | ostrovnoy
# Processing Record 1 of Set 5 | katobu
# Processing Record 2 of Set 5 | altay
# Processing Record 3 of Set 5 | kjollefjord
# Processing Record 4 of Set 5 | butaritari
# Processing Record 5 of Set 5 | kampong thum
# Processing Record 6 of Set 5 | padang
# Processing Record 7 of Set 5 | saskylakh
# Processing Record 8 of Set 5 | ancud
# Processing Record 9 of Set 5 | dawei
# Processing Record 10 of Set 5 | lebu
# Processing Record 11 of Set 5 | whitehorse
# Processing Record 12 of Set 5 | ballina
# Processing Record 13 of Set 5 | urumqi
# Processing Record 14 of Set 5 | baykit
# Processing Record 15 of Set 5 | nikolskoye
# Processing Record 16 of Set 5 | komsomolskiy
# Processing Record 17 of Set 5 | yatou
# Processing Record 18 of Set 5 | yar-sale
# Processing Record 19 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 5 | bac lieu
# Processing Record 21 of Set 5 | blagoyevo
# Processing Record 22 of Set 5 | kardla
# Processing Record 23 of Set 5 | husavik
# Processing Record 24 of Set 5 | presidencia roque saenz pena
# Processing Record 25 of Set 5 | kenai
# Processing Record 26 of Set 5 | acapulco
# Processing Record 27 of Set 5 | liverpool
# Processing Record 28 of Set 5 | blackwater
# Processing Record 29 of Set 5 | nouakchott
# Processing Record 30 of Set 5 | poum
# Processing Record 31 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 5 | necochea
# Processing Record 33 of Set 5 | baker city
# Processing Record 34 of Set 5 | chapais
# Processing Record 35 of Set 5 | matelandia
# Processing Record 36 of Set 5 | saint george
# Processing Record 37 of Set 5 | nipawin
# Processing Record 38 of Set 5 | chuy
# Processing Record 39 of Set 5 | upernavik
# Processing Record 40 of Set 5 | korgen
# Processing Record 41 of Set 5 | fort frances
# Processing Record 42 of Set 5 | lata
# Processing Record 43 of Set 5 | sioux lookout
# Processing Record 44 of Set 5 | pangnirtung
# Processing Record 45 of Set 5 | gravdal
# Processing Record 46 of Set 5 | amapa
# Processing Record 47 of Set 5 | bengkulu
# Processing Record 48 of Set 5 | nantucket
# Processing Record 49 of Set 5 | praia
# Processing Record 50 of Set 5 | guaratinga
# Processing Record 1 of Set 6 | stephenville
# Processing Record 2 of Set 6 | souillac
# Processing Record 3 of Set 6 | verkhnetulomskiy
# Processing Record 4 of Set 6 | kidal
# Processing Record 5 of Set 6 | lashio
# Processing Record 6 of Set 6 | bethel
# Processing Record 7 of Set 6 | namibe
# Processing Record 8 of Set 6 | ransang
# Processing Record 9 of Set 6 | charleston
# Processing Record 10 of Set 6 | oranjestad
# Processing Record 11 of Set 6 | ofunato
# Processing Record 12 of Set 6 | evensk
# Processing Record 13 of Set 6 | vaitape
# Processing Record 14 of Set 6 | mitsamiouli
# Processing Record 15 of Set 6 | cayenne
# Processing Record 16 of Set 6 | adzope
# Processing Record 17 of Set 6 | goderich
# Processing Record 18 of Set 6 | roma
# Processing Record 19 of Set 6 | asau
# Processing Record 20 of Set 6 | oistins
# Processing Record 21 of Set 6 | naze
# Processing Record 22 of Set 6 | gigmoto
# Processing Record 23 of Set 6 | kavieng
# Processing Record 24 of Set 6 | cachoeira do sul
# Processing Record 25 of Set 6 | manta
# Processing Record 26 of Set 6 | yinchuan
# Processing Record 27 of Set 6 | gamba
# Processing Record 28 of Set 6 | ornskoldsvik
# Processing Record 29 of Set 6 | aksu
# Processing Record 30 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 31 of Set 6 | weligama
# Processing Record 32 of Set 6 | gardez
# Processing Record 33 of Set 6 | hasaki
# Processing Record 34 of Set 6 | aklavik
# Processing Record 35 of Set 6 | truth or consequences
# Processing Record 36 of Set 6 | bubaque
# Processing Record 37 of Set 6 | talnakh
# Processing Record 38 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 6 | san nicolas
# Processing Record 40 of Set 6 | la paz
# Processing Record 41 of Set 6 | sayat
# Processing Record 42 of Set 6 | puri
# Processing Record 43 of Set 6 | buchanan
# Processing Record 44 of Set 6 | kampong cham
# Processing Record 45 of Set 6 | chokurdakh
# Processing Record 46 of Set 6 | taga
# Processing Record 47 of Set 6 | tuatapere
# Processing Record 48 of Set 6 | juliaca
# Processing Record 49 of Set 6 | omutinskoye
# City not found. Skipping...
# Processing Record 50 of Set 6 | ubinskoye
# Processing Record 1 of Set 7 | balkanabat
# Processing Record 2 of Set 7 | iquitos
# Processing Record 3 of Set 7 | rio cuarto
# Processing Record 4 of Set 7 | koungou
# Processing Record 5 of Set 7 | yerbogachen
# Processing Record 6 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 7 of Set 7 | show low
# Processing Record 8 of Set 7 | atherton
# Processing Record 9 of Set 7 | hualmay
# Processing Record 10 of Set 7 | karpuninskiy
# City not found. Skipping...
# Processing Record 11 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 7 | high rock
# Processing Record 13 of Set 7 | khatanga
# Processing Record 14 of Set 7 | dublin
# Processing Record 15 of Set 7 | nouadhibou
# Processing Record 16 of Set 7 | horsham
# Processing Record 17 of Set 7 | makasar
# Processing Record 18 of Set 7 | chatra
# Processing Record 19 of Set 7 | hoyanger
# Processing Record 20 of Set 7 | saiha
# Processing Record 21 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 7 | kutum
# Processing Record 23 of Set 7 | huambo
# Processing Record 24 of Set 7 | ipira
# Processing Record 25 of Set 7 | tezu
# Processing Record 26 of Set 7 | half moon bay
# Processing Record 27 of Set 7 | catia la mar
# Processing Record 28 of Set 7 | villazon
# Processing Record 29 of Set 7 | huntsville
# Processing Record 30 of Set 7 | asosa
# Processing Record 31 of Set 7 | terrace
# Processing Record 32 of Set 7 | road town
# Processing Record 33 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 7 | port hardy
# Processing Record 35 of Set 7 | korla
# Processing Record 36 of Set 7 | muros
# Processing Record 37 of Set 7 | verkhnyaya inta
# Processing Record 38 of Set 7 | laguna
# Processing Record 39 of Set 7 | bambous virieux
# Processing Record 40 of Set 7 | elko
# Processing Record 41 of Set 7 | svetlyy
# Processing Record 42 of Set 7 | alice springs
# Processing Record 43 of Set 7 | tomatlan
# Processing Record 44 of Set 7 | intipuca
# Processing Record 45 of Set 7 | shirokiy
# Processing Record 46 of Set 7 | tommot
# Processing Record 47 of Set 7 | xique-xique
# Processing Record 48 of Set 7 | moura
# Processing Record 49 of Set 7 | samana
# Processing Record 50 of Set 7 | sambava
# Processing Record 1 of Set 8 | rawson
# Processing Record 2 of Set 8 | porbandar
# Processing Record 3 of Set 8 | los llanos de aridane
# Processing Record 4 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 8 | mackenzie
# Processing Record 6 of Set 8 | toora-khem
# Processing Record 7 of Set 8 | hampton
# Processing Record 8 of Set 8 | tocantinopolis
# City not found. Skipping...
# Processing Record 9 of Set 8 | iqaluit
# Processing Record 10 of Set 8 | kendari
# Processing Record 11 of Set 8 | naftah
# City not found. Skipping...
# Processing Record 12 of Set 8 | bonthe
# Processing Record 13 of Set 8 | sycow
# Processing Record 14 of Set 8 | burns lake
# Processing Record 15 of Set 8 | conakry
# Processing Record 16 of Set 8 | haines junction
# Processing Record 17 of Set 8 | torbay
# Processing Record 18 of Set 8 | fortuna
# Processing Record 19 of Set 8 | gisborne
# Processing Record 20 of Set 8 | sobolevo
# Processing Record 21 of Set 8 | thunder bay
# Processing Record 22 of Set 8 | college
# Processing Record 23 of Set 8 | matanzas
# Processing Record 24 of Set 8 | entre rios
# Processing Record 25 of Set 8 | magistralnyy
# Processing Record 26 of Set 8 | agadir
# Processing Record 27 of Set 8 | honningsvag
# Processing Record 28 of Set 8 | qaqortoq
# Processing Record 29 of Set 8 | karpathos
# Processing Record 30 of Set 8 | sucha beskidzka
# Processing Record 31 of Set 8 | morgan city
# Processing Record 32 of Set 8 | druzhba
# Processing Record 33 of Set 8 | kieta
# Processing Record 34 of Set 8 | paso de los toros
# Processing Record 35 of Set 8 | katangli
# Processing Record 36 of Set 8 | kaeo
# Processing Record 37 of Set 8 | perth
# Processing Record 38 of Set 8 | anaco
# Processing Record 39 of Set 8 | kuching
# Processing Record 40 of Set 8 | anadyr
# Processing Record 41 of Set 8 | pueblo nuevo
# Processing Record 42 of Set 8 | pocone
# Processing Record 43 of Set 8 | lima
# Processing Record 44 of Set 8 | egvekinot
# Processing Record 45 of Set 8 | san carlos de bariloche
# Processing Record 46 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 47 of Set 8 | paramirim
# Processing Record 48 of Set 8 | shubarshi
# Processing Record 49 of Set 8 | russell
# Processing Record 50 of Set 8 | chernyy yar
# Processing Record 1 of Set 9 | general higinio morinigo
# Processing Record 2 of Set 9 | krasnoselkup
# Processing Record 3 of Set 9 | sao joao da barra
# Processing Record 4 of Set 9 | port-gentil
# Processing Record 5 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 6 of Set 9 | cradock
# Processing Record 7 of Set 9 | xai-xai
# Processing Record 8 of Set 9 | morecambe
# Processing Record 9 of Set 9 | ko samui
# Processing Record 10 of Set 9 | kudymkar
# Processing Record 11 of Set 9 | mount gambier
# Processing Record 12 of Set 9 | akyab
# Processing Record 13 of Set 9 | luderitz
# Processing Record 14 of Set 9 | mudyuga
# City not found. Skipping...
# Processing Record 15 of Set 9 | inhambane
# Processing Record 16 of Set 9 | coracao de jesus
# Processing Record 17 of Set 9 | ayan
# Processing Record 18 of Set 9 | meulaboh
# Processing Record 19 of Set 9 | saurimo
# Processing Record 20 of Set 9 | yumen
# Processing Record 21 of Set 9 | mashhad
# Processing Record 22 of Set 9 | grants
# Processing Record 23 of Set 9 | upata
# Processing Record 24 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 9 | farah
# Processing Record 26 of Set 9 | mustafabad
# Processing Record 27 of Set 9 | mindelo
# Processing Record 28 of Set 9 | kapoeta
# Processing Record 29 of Set 9 | labuhan
# Processing Record 30 of Set 9 | sarh
# Processing Record 31 of Set 9 | fairbanks
# Processing Record 32 of Set 9 | wum
# Processing Record 33 of Set 9 | betsiamites
# Processing Record 34 of Set 9 | piacabucu
# Processing Record 35 of Set 9 | ilulissat
# Processing Record 36 of Set 9 | celestun
# Processing Record 37 of Set 9 | emba
# Processing Record 38 of Set 9 | ishigaki
# Processing Record 39 of Set 9 | znamenskoye
# Processing Record 40 of Set 9 | nuuk
# Processing Record 41 of Set 9 | broken hill
# Processing Record 42 of Set 9 | vostok
# Processing Record 43 of Set 9 | xuanhua
# Processing Record 44 of Set 9 | kahului
# Processing Record 45 of Set 9 | orumiyeh
# Processing Record 46 of Set 9 | havre-saint-pierre
# Processing Record 47 of Set 9 | brandon
# Processing Record 48 of Set 9 | sanghar
# Processing Record 49 of Set 9 | namie
# Processing Record 50 of Set 9 | henties bay
# Processing Record 1 of Set 10 | tarakan
# Processing Record 2 of Set 10 | leningradskiy
# Processing Record 3 of Set 10 | salalah
# Processing Record 4 of Set 10 | burica
# City not found. Skipping...
# Processing Record 5 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 6 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 7 of Set 10 | poquoson
# Processing Record 8 of Set 10 | mizdah
# Processing Record 9 of Set 10 | high level
# Processing Record 10 of Set 10 | faya
# Processing Record 11 of Set 10 | seleron
# Processing Record 12 of Set 10 | nizhniy baskunchak
# Processing Record 13 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 10 | paamiut
# Processing Record 15 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 10 | nioro
# Processing Record 17 of Set 10 | rondonopolis
# Processing Record 18 of Set 10 | parana
# Processing Record 19 of Set 10 | bereznik
# Processing Record 20 of Set 10 | kaitangata
# Processing Record 21 of Set 10 | omboue
# Processing Record 22 of Set 10 | novikovo
# Processing Record 23 of Set 10 | pevek
# Processing Record 24 of Set 10 | sasovo
# Processing Record 25 of Set 10 | kastamonu
# Processing Record 26 of Set 10 | shitanjing
# Processing Record 27 of Set 10 | cam pha
# City not found. Skipping...
# Processing Record 28 of Set 10 | unye
# City not found. Skipping...
# Processing Record 29 of Set 10 | saldanha
# Processing Record 30 of Set 10 | ridgecrest
# Processing Record 31 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 32 of Set 10 | sindou
# Processing Record 33 of Set 10 | sarangani
# Processing Record 34 of Set 10 | balykshi
# Processing Record 35 of Set 10 | merrill
# Processing Record 36 of Set 10 | taltal
# Processing Record 37 of Set 10 | arequipa
# Processing Record 38 of Set 10 | guayaramerin
# Processing Record 39 of Set 10 | tambacounda
# Processing Record 40 of Set 10 | dolni dabnik
# Processing Record 41 of Set 10 | swan river
# Processing Record 42 of Set 10 | varhaug
# Processing Record 43 of Set 10 | belle fourche
# Processing Record 44 of Set 10 | floro
# Processing Record 45 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 10 | homer
# Processing Record 47 of Set 10 | sur
# Processing Record 48 of Set 10 | tres arroyos
# Processing Record 49 of Set 10 | tawang
# Processing Record 50 of Set 10 | sovetskiy
# Processing Record 1 of Set 11 | soure
# Processing Record 2 of Set 11 | coahuayana
# Processing Record 3 of Set 11 | ruidoso
# Processing Record 4 of Set 11 | costinesti
# Processing Record 5 of Set 11 | kushmurun
# Processing Record 6 of Set 11 | ahipara
# Processing Record 7 of Set 11 | marawi
# Processing Record 8 of Set 11 | nyaunglebin
# Processing Record 9 of Set 11 | charagua
# Processing Record 10 of Set 11 | cabra
# Processing Record 11 of Set 11 | andenes
# Processing Record 12 of Set 11 | esmeraldas
# Processing Record 13 of Set 11 | buka
# Processing Record 14 of Set 11 | avera
# Processing Record 15 of Set 11 | mala
# Processing Record 16 of Set 11 | tangshan
# Processing Record 17 of Set 11 | yokadouma
# Processing Record 18 of Set 11 | duz
# City not found. Skipping...
# Processing Record 19 of Set 11 | manado
# Processing Record 20 of Set 11 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 21 of Set 11 | corn island
# Processing Record 22 of Set 11 | bathsheba
# Processing Record 23 of Set 11 | rantepao
# Processing Record 24 of Set 11 | rawatbhata
# Processing Record 25 of Set 11 | barcelos
# Processing Record 26 of Set 11 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 27 of Set 11 | erenhot
# Processing Record 28 of Set 11 | kedrovyy
# Processing Record 29 of Set 11 | taraz
# Processing Record 30 of Set 11 | rudnya
# Processing Record 31 of Set 11 | sao jose da coroa grande
# Processing Record 32 of Set 11 | ormara
# Processing Record 33 of Set 11 | peniche
# Processing Record 34 of Set 11 | filingue
# Processing Record 35 of Set 11 | maneadero
# Processing Record 36 of Set 11 | ihlow
# Processing Record 37 of Set 11 | jiaohe
# Processing Record 38 of Set 11 | rio de janeiro
# Processing Record 39 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 11 | raga
# Processing Record 41 of Set 11 | massakory
# Processing Record 42 of Set 11 | awbari
# Processing Record 43 of Set 11 | margate
# Processing Record 44 of Set 11 | bury saint edmunds
# City not found. Skipping...
# Processing Record 45 of Set 11 | gizo
# Processing Record 46 of Set 11 | hambantota
# Processing Record 47 of Set 11 | harper
# Processing Record 48 of Set 11 | outlook
# Processing Record 49 of Set 11 | kasongo-lunda
# Processing Record 50 of Set 11 | barra dos coqueiros
# Processing Record 1 of Set 12 | doka
# Processing Record 2 of Set 12 | kamenka
# Processing Record 3 of Set 12 | nuqui
# Processing Record 4 of Set 12 | beringovskiy
# Processing Record 5 of Set 12 | sidi ali
# Processing Record 6 of Set 12 | karaidel
# Processing Record 7 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 12 | praia da vitoria
# Processing Record 9 of Set 12 | djambala
# Processing Record 10 of Set 12 | broome
# Processing Record 11 of Set 12 | vagur
# Processing Record 12 of Set 12 | forbes
# Processing Record 13 of Set 12 | pimentel
# Processing Record 14 of Set 12 | tautira
# Processing Record 15 of Set 12 | dubbo
# Processing Record 16 of Set 12 | chudniv
# Processing Record 17 of Set 12 | karakol
# Processing Record 18 of Set 12 | tias
# Processing Record 19 of Set 12 | fukuma
# Processing Record 20 of Set 12 | lorengau
# Processing Record 21 of Set 12 | carman
# Processing Record 22 of Set 12 | jaltenango
# Processing Record 23 of Set 12 | havelock
# Processing Record 24 of Set 12 | olafsvik
# Processing Record 25 of Set 12 | maceio
# Processing Record 26 of Set 12 | lucapa
# Processing Record 27 of Set 12 | hay river
# Processing Record 28 of Set 12 | meadow lake
# Processing Record 29 of Set 12 | pamanukan
# Processing Record 30 of Set 12 | udaipura
# Processing Record 31 of Set 12 | kuppam
# Processing Record 32 of Set 12 | komsomolets
# Processing Record 33 of Set 12 | labrea
# Processing Record 34 of Set 12 | novi sanzhary
# Processing Record 35 of Set 12 | maykain
# City not found. Skipping...
# Processing Record 36 of Set 12 | guanica
# Processing Record 37 of Set 12 | san quintin
# Processing Record 38 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 39 of Set 12 | malartic
# Processing Record 40 of Set 12 | lovozero
# Processing Record 41 of Set 12 | longhua
# Processing Record 42 of Set 12 | tessalit
# Processing Record 43 of Set 12 | nemuro
# Processing Record 44 of Set 12 | nongan
# Processing Record 45 of Set 12 | malakal
# Processing Record 46 of Set 12 | san pedro
# Processing Record 47 of Set 12 | atar
# Processing Record 48 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 49 of Set 12 | fare
# Processing Record 50 of Set 12 | bakchar
# Processing Record 1 of Set 13 | domoni
# Processing Record 2 of Set 13 | makakilo city
# Processing Record 3 of Set 13 | slave lake
# Processing Record 4 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 5 of Set 13 | sogdiondon
# City not found. Skipping...
# Processing Record 6 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 13 | tabou
# Processing Record 8 of Set 13 | uravakonda
# Processing Record 9 of Set 13 | atka
# City not found. Skipping...
# Processing Record 10 of Set 13 | tacuarembo
# Processing Record 11 of Set 13 | rocha
# Processing Record 12 of Set 13 | port macquarie
# Processing Record 13 of Set 13 | botshabelo
# Processing Record 14 of Set 13 | pilot butte
# Processing Record 15 of Set 13 | san jose
# Processing Record 16 of Set 13 | sola
# Processing Record 17 of Set 13 | kavaratti
# Processing Record 18 of Set 13 | tabuk
# Processing Record 19 of Set 13 | verkhoyansk
# Processing Record 20 of Set 13 | ennis
# Processing Record 21 of Set 13 | jiayuguan
# Processing Record 22 of Set 13 | porto novo
# Processing Record 23 of Set 13 | mehriz
# Processing Record 24 of Set 13 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 25 of Set 13 | los andes
# Processing Record 26 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 27 of Set 13 | ruvo di puglia
# Processing Record 28 of Set 13 | maumere
# Processing Record 29 of Set 13 | barstow
# Processing Record 30 of Set 13 | hare bay
# Processing Record 31 of Set 13 | termoli
# Processing Record 32 of Set 13 | lagunas
# Processing Record 33 of Set 13 | sawtell
# Processing Record 34 of Set 13 | finkenstein
# Processing Record 35 of Set 13 | cairns
# Processing Record 36 of Set 13 | cascais
# Processing Record 37 of Set 13 | lasa
# Processing Record 38 of Set 13 | ninghai
# Processing Record 39 of Set 13 | jalu
# Processing Record 40 of Set 13 | sinjah
# City not found. Skipping...
# Processing Record 41 of Set 13 | mikuni
# Processing Record 42 of Set 13 | livingston
# Processing Record 43 of Set 13 | la romana
# Processing Record 44 of Set 13 | pacific grove
# Processing Record 45 of Set 13 | viedma
# Processing Record 46 of Set 13 | hailar
# Processing Record 47 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 13 | pangai
# Processing Record 49 of Set 13 | vila velha
# Processing Record 50 of Set 13 | muswellbrook
# Processing Record 1 of Set 14 | uni
# Processing Record 2 of Set 14 | buluang
# Processing Record 3 of Set 14 | tawnat
# City not found. Skipping...
# Processing Record 4 of Set 14 | priiskovyy
# Processing Record 5 of Set 14 | kitgum
# Processing Record 6 of Set 14 | nawa
# Processing Record 7 of Set 14 | itarema
# Processing Record 8 of Set 14 | kiama
# Processing Record 9 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 10 of Set 14 | bongor
# Processing Record 11 of Set 14 | gat
# Processing Record 12 of Set 14 | price
# Processing Record 13 of Set 14 | vieste
# Processing Record 14 of Set 14 | belmonte
# Processing Record 15 of Set 14 | san cristobal
# Processing Record 16 of Set 14 | north bend
# Processing Record 17 of Set 14 | bosaso
# Processing Record 18 of Set 14 | santa isabel
# Processing Record 19 of Set 14 | kloulklubed
# Processing Record 20 of Set 14 | porto walter
# Processing Record 21 of Set 14 | tahoua
# Processing Record 22 of Set 14 | ulvik
# Processing Record 23 of Set 14 | acarau
# Processing Record 24 of Set 14 | luanda
# Processing Record 25 of Set 14 | shieli
# Processing Record 26 of Set 14 | grand-santi
# Processing Record 27 of Set 14 | komarikhinskiy
# Processing Record 28 of Set 14 | daru
# Processing Record 29 of Set 14 | minab
# Processing Record 30 of Set 14 | nabire
# Processing Record 31 of Set 14 | marzuq
# Processing Record 32 of Set 14 | mumbwa
# Processing Record 33 of Set 14 | saint-francois
# Processing Record 34 of Set 14 | nueva loja
# Processing Record 35 of Set 14 | damaturu
# Processing Record 36 of Set 14 | vitoria da conquista
# Processing Record 37 of Set 14 | sharan
# Processing Record 38 of Set 14 | antalaha
# Processing Record 39 of Set 14 | samarai
# Processing Record 40 of Set 14 | saint anthony
# Processing Record 41 of Set 14 | hamilton
# Processing Record 42 of Set 14 | la serena
# Processing Record 43 of Set 14 | orlik
# Processing Record 44 of Set 14 | hatton
# Processing Record 45 of Set 14 | lazaro cardenas
# Processing Record 46 of Set 14 | muisne
# Processing Record 47 of Set 14 | marystown
# Processing Record 48 of Set 14 | josefina
# Processing Record 49 of Set 14 | rumoi
# Processing Record 50 of Set 14 | jiexiu
# Processing Record 1 of Set 15 | mantua
# Processing Record 2 of Set 15 | dingli
# Processing Record 3 of Set 15 | sena madureira
# Processing Record 4 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 5 of Set 15 | sorong
# Processing Record 6 of Set 15 | marrakesh
# Processing Record 7 of Set 15 | manicore
# Processing Record 8 of Set 15 | emerald
# Processing Record 9 of Set 15 | ptuj
# Processing Record 10 of Set 15 | kafar kama
# City not found. Skipping...
# Processing Record 11 of Set 15 | de aar
# Processing Record 12 of Set 15 | saint-jean-port-joli
# Processing Record 13 of Set 15 | lagoa
# Processing Record 14 of Set 15 | imeni zhelyabova
# Processing Record 15 of Set 15 | erzin
# Processing Record 16 of Set 15 | anuchino
# Processing Record 17 of Set 15 | rovaniemi
# Processing Record 18 of Set 15 | ambilobe
# Processing Record 19 of Set 15 | mocuba
# Processing Record 20 of Set 15 | sayyan
# Processing Record 21 of Set 15 | watsa
# Processing Record 22 of Set 15 | francistown
# Processing Record 23 of Set 15 | balkhash
# Processing Record 24 of Set 15 | sakakah
# Processing Record 25 of Set 15 | bull savanna
# Processing Record 26 of Set 15 | rio grande
# Processing Record 27 of Set 15 | inndyr
# Processing Record 28 of Set 15 | alihe
# Processing Record 29 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 15 | hovd
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Cockburn Town  21.4612  -71.1419     78.76        65          40
# 1         Avarua -21.2078 -159.7750     82.45        78          40
# 2           Tahe  52.3333  124.7333     15.19        93          97
# 3        Mataura -46.1927  168.8643     61.32        69           4
# 4         Hobart -42.8794  147.3294     64.26        74           0
# 5      Coihaique -45.5752  -72.0662     48.81        93         100
# 6         Lompoc  34.6391 -120.4579     66.85        65         100
# 7          Bluff -46.6000  168.3333     56.16        82          11
# 8    New Norfolk -42.7826  147.0587     63.91        61          92
# 9         Kodiak  57.7900 -152.4072     33.31       100         100
#
#    Wind Speed Country   Current Description
# 0       11.50      TC      scattered clouds
# 1       10.36      CK      scattered clouds
# 2        3.65      CN       overcast clouds
# 3        2.46      NZ             clear sky
# 4        8.05      AU  heavy intensity rain
# 5        6.91      CL            light rain
# 6       31.00      US       overcast clouds
# 7        3.98      NZ            few clouds
# 8        2.19      AU       overcast clouds
# 9       31.07      US            heavy snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
